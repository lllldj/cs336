# %%
import os
import torch
import torch.nn as nn
import numpy as np
import random
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import numpy as np
#
# File ~/workspace/cs336/assignment1/.venv/lib/python3.12/site-packages/torch/__init__.py:405
#     403     if USE_GLOBAL_DEPS:
#     404         _load_global_deps()
# --> 405     from torch._C import *  # noqa: F403
#     408 class SymInt:
#     409     """
#     410     Like an int (including magic methods), but redirects all operations on the
#     411     wrapped node. This is used in particular to symbolically record operations
#     412     in the symbolic shape workflow.
#     413     """
#
# ImportError: libcudnn.so.9: cannot open shared object file: No such file or directory

# %%
def get_batch_from_data(dataset, batch_size, context_len, device):
    sts = [random.randint(0,len(dataset)-context_len-2) for _ in range(batch_size)]
    data_load = [dataset[st:st+context_len] for st in sts]
    target = [dataset[st+1:st+context_len+1] for st in sts]
    return torch.tensor(data_load,device=device),torch.tensor(target,device=device)
